# %%
# Importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from mlxtend.plotting import plot_decision_regions
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Import Breast Cancer Data

# %%
df = pd.read_csv('breast_cancer.csv')
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# # Consider 2 features and map it as x and outcome as y

# %% [markdown]
# # Train and Test split

# %%
x  =  df.iloc[:,:2].values
y =  df.outcome.values
x
# Out:
# array([[17.99, 10.38],
#        [20.57, 17.77],
#        [19.69, 21.25],
#        ...,
#        [16.6 , 28.08],
#        [20.6 , 29.33],
#        [ 7.76, 24.54]])

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.20, random_state=100)

# %% [markdown]
# # Initializing the classifier and Modify the C and Gamma value to view the plot

# %%
# Try with different C value to check the plot
svm = SVC(C=200.0,kernel='rbf',gamma=0.05,verbose=True,random_state=100)

#note degree will be ignored by rbf

# %%
svm.fit(x_train,y_train)
# Out:
# [LibSVM]
# SVC(C=200.0, gamma=0.05, random_state=100, verbose=True)

# %%
# Use plot decision region in 2 dimension

# Adding axes annotations
plot_decision_regions(x_train, y_train,clf=svm, legend =2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Prediction for RBF Kernal

# %%
model_prediction =  svm.predict(x_test)

# %%
from sklearn.metrics import accuracy_score , recall_score , precision_score , f1_score, confusion_matrix
print("accuracy score:" , accuracy_score(y_test , model_prediction))
print("precision score:" , precision_score(y_test , model_prediction))
print("recall:" , recall_score(y_test , model_prediction))
print("f1 score:" , f1_score(y_test , model_prediction))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-db89587b0d31> in <module>
#       1 from sklearn.metrics import accuracy_score , recall_score , precision_score , f1_score, confusion_matrix
# ----> 2 print("accuracy score:" , accuracy_score(y_test , model_prediction))
#       3 print("precision score:" , precision_score(y_test , model_prediction))
#       4 print("recall:" , recall_score(y_test , model_prediction))
#       5 print("f1 score:" , f1_score(y_test , model_prediction))
#
# NameError: name 'model_prediction' is not defined

# %% [markdown]
# # Linear SVM

# %%
svm = SVC(C=200, kernel='linear')
svm.fit(x_train,y_train)
# Use plot decision region in 2 dimension
#pca = PCA(n_components = 2)
# Adding axes annotations
plot_decision_regions(x_train, y_train,clf=svm, legend =2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Prediction with Linear SVM

# %%
model_prediction =  svm.predict(x_test)
from sklearn.metrics import accuracy_score , recall_score , precision_score , f1_score, confusion_matrix
print("accuracy score:" , accuracy_score(y_test , model_prediction))
print("precision score:" , precision_score(y_test , model_prediction))
print("recall:" , recall_score(y_test , model_prediction))
print("f1 score:" , f1_score(y_test , model_prediction))
# Out:
# accuracy score: 0.8859649122807017
# precision score: 0.9090909090909091
# recall: 0.8163265306122449
# f1 score: 0.8602150537634408

# %% [markdown]
# # Polynomial Kernal

# %%
svm = SVC(C=200, kernel='poly')
svm.fit(x_train,y_train)
# Use plot decision region in 2 dimension
#pca = PCA(n_components = 2)
# Adding axes annotations
plot_decision_regions(x_train, y_train,clf=svm, legend =2)
# Adding axes annotations
plt.xlabel('Mean Radius [cm]')
plt.ylabel('Mean Texure [cm]')
plt.title('Breast Cancer Plot')

plt.show()

# %% [markdown]
# # Prediction with Polynomial Kernal

# %%
model_prediction =  svm.predict(x_test)
from sklearn.metrics import accuracy_score , recall_score , precision_score , f1_score, confusion_matrix
print("accuracy score:" , accuracy_score(y_test , model_prediction))
print("precision score:" , precision_score(y_test , model_prediction))
print("recall:" , recall_score(y_test , model_prediction))
print("f1 score:" , f1_score(y_test , model_prediction))
# Out:
# accuracy score: 0.9035087719298246
# precision score: 0.9318181818181818
# recall: 0.8367346938775511
# f1 score: 0.8817204301075268

# %% [markdown]
# # Ploynomial Kernal with different degree

# %%
for i in range(2,6):
    svm = SVC(C=100, kernel='poly', degree = i)
    svm.fit(x_train,y_train)
    # Use plot decision region in 2 dimension
    #pca = PCA(n_components = 2)
    # Adding axes annotations
    plot_decision_regions(x_train, y_train,clf=svm, legend =2)
    # Adding axes annotations
    plt.xlabel('Mean Radius [cm]')
    plt.ylabel('Mean Texure [cm]')
    plt.title('Breast Cancer Plot')
    plt.show()
    model_prediction =  svm.predict(x_test)
    from sklearn.metrics import accuracy_score , recall_score , precision_score , f1_score, confusion_matrix
    print("accuracy score:" , accuracy_score(y_test , model_prediction))
    print("precision score:" , precision_score(y_test , model_prediction))
    print("recall:" , recall_score(y_test , model_prediction))
    print("f1 score:" , f1_score(y_test , model_prediction))
# Out:
# accuracy score: 0.8859649122807017
# precision score: 0.9090909090909091
# recall: 0.8163265306122449
# f1 score: 0.8602150537634408
# accuracy score: 0.9035087719298246
# precision score: 0.9318181818181818
# recall: 0.8367346938775511
# f1 score: 0.8817204301075268
# accuracy score: 0.9035087719298246
# precision score: 0.9318181818181818
# recall: 0.8367346938775511
# f1 score: 0.8817204301075268
# accuracy score: 0.8947368421052632
# precision score: 0.9302325581395349
# recall: 0.8163265306122449
# f1 score: 0.8695652173913043

# %% [markdown]
# # RBF with different gamma and constant C value

# %%
gamma = [0.1, 1,10,50,100,150,200,500,750,1000]
for i in range(len(gamma)):
    svm = SVC(C=100.0,kernel='rbf',degree=3,gamma=gamma[i],verbose=True,random_state=100)
    svm.fit(x_train,y_train)
    # Use plot decision region in 2 dimension
    #pca = PCA(n_components = 2)
    # Adding axes annotations
    plot_decision_regions(x_train, y_train,clf=svm, legend =2)
      # Adding axes annotations
    plt.xlabel('Mean Radius [cm]')
    plt.ylabel('Mean Texure [cm]')
    plt.title('Breast Cancer Plot')
    plt.show()
    model_prediction =  svm.predict(x_test)
    from sklearn.metrics import accuracy_score , recall_score 
    precision_score , f1_score, confusion_matrix
    print("accuracy score:" , accuracy_score(y_test , model_prediction))
    print("precision score:" , precision_score(y_test , model_prediction))
    print("recall:" , recall_score(y_test , model_prediction))
    print("f1 score:" , f1_score(y_test , model_prediction))
# Out:
# [LibSVM]
# accuracy score: 0.868421052631579
# precision score: 0.9047619047619048
# recall: 0.7755102040816326
# f1 score: 0.8351648351648353
# [LibSVM]
# accuracy score: 0.7982456140350878
# precision score: 0.8611111111111112
# recall: 0.6326530612244898
# f1 score: 0.7294117647058823
# [LibSVM]
# accuracy score: 0.7192982456140351
# precision score: 0.84
# recall: 0.42857142857142855
# f1 score: 0.5675675675675675
# [LibSVM]
# accuracy score: 0.5964912280701754
# precision score: 0.8
# recall: 0.08163265306122448
# f1 score: 0.1481481481481481
# [LibSVM]
# accuracy score: 0.5877192982456141
# precision score: 1.0
# recall: 0.04081632653061224
# f1 score: 0.07843137254901959
# [LibSVM]
# accuracy score: 0.5701754385964912
# precision score: 0.0
# recall: 0.0
# f1 score: 0.0
# [LibSVM]
# accuracy score: 0.5701754385964912
# precision score: 0.0
# recall: 0.0
# f1 score: 0.0
# [LibSVM]
# accuracy score: 0.5701754385964912
# precision score: 0.0
# recall: 0.0
# f1 score: 0.0
# ...

# %% [markdown]
# # RBF with different C value and constant Gamma

# %%
c = [0.1,1,10,50,100,150,200,500,750,1000]
for i in range(len(c)):
    svm = SVC(C=c[i],kernel='rbf',degree=3,gamma=0.5,verbose=True,random_state=100)
    svm.fit(x_train,y_train)
    # Use plot decision region in 2 dimension
    #pca = PCA(n_components = 2)
    # Adding axes annotations
    plot_decision_regions(x_train, y_train,clf=svm, legend =2)
      # Adding axes annotations
    plt.xlabel('Mean Radius [cm]')
    plt.ylabel('Mean Texure [cm]')
    plt.title('Breast Cancer Plot for C value:'+str(c[i]))
    plt.show()
# Out:
# [LibSVM]
# [LibSVM]
# [LibSVM]
# [LibSVM]
# [LibSVM]
# [LibSVM]
# [LibSVM]
# [LibSVM]
# [LibSVM]
# [LibSVM]
