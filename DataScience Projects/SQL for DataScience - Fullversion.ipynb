# %% [raw]
# SQLAlchemy is a library that facilitates the communication between Python programs and databases. Most of the times, this library is used as an Object Relational Mapper (ORM) tool that translates Python classes to tables on relational databases and automatically converts function calls to SQL statements.

# %% [raw]
# PyMySQL is an interface for connecting to a MySQL database server from Python. It implements the Python Database API v2. 0 and contains a pure-Python MySQL client library. The goal of PyMySQL is to be a drop-in replacement for MySQLdb.

# %%
# !pip install sqlalchemy
# !pip install pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (1.3.20)
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
db_host = '18.136.157.135:3306' # port: 3306
username = 'dm_user_sql'
user_pass = '37z49REb$nK@nlpV!vJ'
db_name = 'datamites_sql'

conn = create_engine('mysql+pymysql://'+username+':'+user_pass+'@'+db_host+'/'+db_name)
conn.table_names()
# Out:
# ['customers', 'orders', 'products']

# %%
query = "select * from orders" # SQL statement
orders = pd.read_sql(query,conn)
print(orders.shape)
orders
# Out:
# (9, 6)
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %%
query = "select * from customers"
customers = pd.read_sql(query,conn)
print(customers.shape)
customers
# Out:
# (10, 5)
#   customer_id       customer_name             city           state  \
# 0    AA-10480        Andrew Allen          Concord  North Carolina
# 1    AG-10270     Alejandro Grove      West Jordan            Utah
# 2    BH-11710     Brosina Hoffman      Los Angeles      California
# 3    CG-12520         Claire Gute        Henderson        Kentucky
# 4    DV-13045     Darrin Van Huff      Los Angeles      California
# 5    HP-14815       Harold Pawlan       Fort Worth           Texas
# 6    IM-15070        Irene Maddox          Seattle      Washington
# 7    PK-19075           Pete Kriz          Madison       Wisconsin
# 8    SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 9    ZD-21925  Zuschuss Donatelli    San Francisco      California
#
#    postal_code
# 0        28027
# 1        84084
# 2        90032
# 3        42420
# 4        90036
# 5        76106
# 6        98103
# 7        53711
# 8        33311
# 9        94109

# %%
query = "select * from products"
products = pd.read_sql(query,conn)
print(products.shape)
products
# Out:
# (14, 4)
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10001539        Furniture       Tables
# 5   OFF-AP-10002892  Office Supplies   Appliances
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   OFF-BI-10003656  Office Supplies      Binders
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-LA-10000240  Office Supplies       Labels
# 10  OFF-PA-10002365  Office Supplies        Paper
# 11  OFF-ST-10000760  Office Supplies      Storage
# 12  TEC-PH-10002033       Technology       Phones
# 13  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2   Eldon Expressions Wood and Plastic Desk Access...
# 3       Bretford CR4500 Series Slim Rectangular Table
# 4            Chromcraft Rectangular Conference Tables
# 5                    Belkin F5C206VTEL 6 Outlet Surge
# 6                                          Newell 322
# 7         Fellowes PB200 Plastic Comb Binding Machine
# 8   DXL Angle-View Binders with Locking Rings by S...
# 9   Self-Adhesive Address Labels for Typewriters b...
# 10                                         Xerox 1967
# 11                     Eldon Fold 'N Roll Cart System
# 12    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 13                     Mitel 5320 IP Phone VoIP phone

# %% [markdown]
# # SQL Where Condition

# %%
query = "select * from products where category='Furniture'"
products = pd.read_sql(query,conn)
print(products.shape)
products
# Out:
# (5, 4)
#         product_id   category sub_category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
# 2  FUR-FU-10001487  Furniture  Furnishings
# 3  FUR-TA-10000577  Furniture       Tables
# 4  FUR-TA-10001539  Furniture       Tables
#
#                                         product_name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Eldon Expressions Wood and Plastic Desk Access...
# 3      Bretford CR4500 Series Slim Rectangular Table
# 4           Chromcraft Rectangular Conference Tables

# %% [markdown]
# # SQL Where Condition and logical statement

# %%
query = "select * from products where category='Furniture' or category='Technology'"
products = pd.read_sql(query,conn)
print(products.shape)
products
# Out:
# (7, 4)
#         product_id    category sub_category  \
# 0  FUR-BO-10001798   Furniture    Bookcases
# 1  FUR-CH-10000454   Furniture       Chairs
# 2  FUR-FU-10001487   Furniture  Furnishings
# 3  FUR-TA-10000577   Furniture       Tables
# 4  FUR-TA-10001539   Furniture       Tables
# 5  TEC-PH-10002033  Technology       Phones
# 6  TEC-PH-10002275  Technology       Phones
#
#                                         product_name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Eldon Expressions Wood and Plastic Desk Access...
# 3      Bretford CR4500 Series Slim Rectangular Table
# 4           Chromcraft Rectangular Conference Tables
# 5    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 6                     Mitel 5320 IP Phone VoIP phone

# %%
query = "select * from products where category='Furniture' and category='Technology'"
products = pd.read_sql(query,conn)
print(products.shape)
products
# Out:
# (0, 4)
# Empty DataFrame
# Columns: [product_id, category, sub_category, product_name]
# Index: []

# %% [markdown]
# ## SQL Left Join
# also called as Left Outer Join
# * LEFT OUTER join includes unmatched rows from the left table while RIGHT OUTER join includes unmatched rows from the right side of the table.
#
# * The result of LEFT OUTER join can be seen as INNER JOIN + unmatched rows of left table while the result of the RIGHT OUTER join is equal to INNER JOIN + unmatched rows from the right side table.

# %%
# fechting only customers details who have orders
query = "select * from orders  left join customers on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (9, 11)
#          order_id  order_date customer_id       product_id   sales  quantity  \
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5
#
#   customer_id    customer_name             city           state  postal_code
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311

# %% [markdown]
# ## SQL Right Join
# Also called as Right outer join

# %%
# fechting only customers details who have orders
query = "select * from orders  right join customers on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (14, 11)
#           order_id  order_date customer_id       product_id   sales  quantity  \
# 0   CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860       7.0
# 1   CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530       3.0
# 2   CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620       2.0
# 3   CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960       2.0
# 4   CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620       5.0
# 5   CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552       1.0
# 6   CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552       2.0
# 7   CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552       3.0
# 8   US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650       5.0
# 9             None        None        None             None     NaN       NaN
# 10            None        None        None             None     NaN       NaN
# 11            None        None        None             None     NaN       NaN
# 12            None        None        None             None     NaN       NaN
# 13            None        None        None             None     NaN       NaN
#
#    customer_id       customer_name             city           state  \
# 0     BH-11710     Brosina Hoffman      Los Angeles      California
# 1     BH-11710     Brosina Hoffman      Los Angeles      California
# 2     DV-13045     Darrin Van Huff      Los Angeles      California
# 3     CG-12520         Claire Gute        Henderson        Kentucky
# 4     BH-11710     Brosina Hoffman      Los Angeles      California
# 5     DV-13045     Darrin Van Huff      Los Angeles      California
# 6     SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 7     AA-10480        Andrew Allen          Concord  North Carolina
# 8     SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 9     AG-10270     Alejandro Grove      West Jordan            Utah
# 10    HP-14815       Harold Pawlan       Fort Worth           Texas
# 11    IM-15070        Irene Maddox          Seattle      Washington
# 12    PK-19075           Pete Kriz          Madison       Wisconsin
# 13    ZD-21925  Zuschuss Donatelli    San Francisco      California
#
#     postal_code
# 0         90032
# 1         90032
# 2         90036
# 3         42420
# 4         90032
# 5         90036
# 6         33311
# 7         28027
# 8         33311
# 9         84084
# 10        76106
# 11        98103
# 12        53711
# 13        94109

# %%
# fechting only customers details who have orders
query = "select * from customers  right join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data.head(50)
# Out:
# (9, 11)
#   customer_id    customer_name             city           state  postal_code  \
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
#
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %% [markdown]
# ## SQL Inner Join
# This is default

# %%
# fechting only customers details who have orders
query = "select * from customers  inner join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data.head(50)
# Out:
# (9, 11)
#   customer_id    customer_name             city           state  postal_code  \
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
#
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %% [markdown]
# #  Join multiple tables

# %%
# fechting only customers details who have orders
query = "select * from orders  \
left join customers on orders.customer_id=customers.customer_id \
left join products  on orders.product_id = products.product_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (9, 15)
#          order_id  order_date customer_id       product_id   sales  quantity  \
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5
#
#   customer_id    customer_name             city           state  postal_code  \
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
#
#         product_id         category sub_category  \
# 0  FUR-FU-10001487        Furniture  Furnishings
# 1  FUR-TA-10000577        Furniture       Tables
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-BO-10001798        Furniture    Bookcases
# 4  OFF-LA-10000240  Office Supplies       Labels
# 5  OFF-PA-10002365  Office Supplies        Paper
# 6  OFF-PA-10002365  Office Supplies        Paper
# 7  OFF-PA-10002365  Office Supplies        Paper
# 8  FUR-TA-10000577        Furniture       Tables
#
#                                         product_name
# 0  Eldon Expressions Wood and Plastic Desk Access...
# 1      Bretford CR4500 Series Slim Rectangular Table
# 2  Self-Adhesive Address Labels for Typewriters b...
# 3                  Bush Somerset Collection Bookcase
# 4  Self-Adhesive Address Labels for Typewriters b...
# 5                                         Xerox 1967
# 6                                         Xerox 1967
# 7                                         Xerox 1967
# 8      Bretford CR4500 Series Slim Rectangular Table

# %%
query = "select * from orders  \
left join customers on orders.customer_id=customers.customer_id \
right join products  on orders.product_id = products.product_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (18, 15)
#           order_id  order_date customer_id       product_id   sales  quantity  \
# 0   CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960       2.0
# 1             None        None        None             None     NaN       NaN
# 2   CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860       7.0
# 3   CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530       3.0
# 4   US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650       5.0
# 5             None        None        None             None     NaN       NaN
# 6             None        None        None             None     NaN       NaN
# 7             None        None        None             None     NaN       NaN
# 8             None        None        None             None     NaN       NaN
# 9             None        None        None             None     NaN       NaN
# 10  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620       2.0
# 11  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620       5.0
# 12  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552       1.0
# 13  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552       2.0
# 14  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552       3.0
# 15            None        None        None             None     NaN       NaN
# 16            None        None        None             None     NaN       NaN
# 17            None        None        None             None     NaN       NaN
#
#    customer_id    customer_name             city           state  postal_code  \
# 0     CG-12520      Claire Gute        Henderson        Kentucky      42420.0
# 1         None             None             None            None          NaN
# 2     BH-11710  Brosina Hoffman      Los Angeles      California      90032.0
# 3     BH-11710  Brosina Hoffman      Los Angeles      California      90032.0
# 4     SO-20335   Sean O'Donnell  Fort Lauderdale         Florida      33311.0
# 5         None             None             None            None          NaN
# 6         None             None             None            None          NaN
# 7         None             None             None            None          NaN
# 8         None             None             None            None          NaN
# 9         None             None             None            None          NaN
# 10    DV-13045  Darrin Van Huff      Los Angeles      California      90036.0
# 11    BH-11710  Brosina Hoffman      Los Angeles      California      90032.0
# 12    DV-13045  Darrin Van Huff      Los Angeles      California      90036.0
# 13    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida      33311.0
# 14    AA-10480     Andrew Allen          Concord  North Carolina      28027.0
# 15        None             None             None            None          NaN
# 16        None             None             None            None          NaN
# 17        None             None             None            None          NaN
#
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10000577        Furniture       Tables
# 5   FUR-TA-10001539        Furniture       Tables
# 6   OFF-AP-10002892  Office Supplies   Appliances
# 7   OFF-AR-10002833  Office Supplies          Art
# 8   OFF-BI-10003656  Office Supplies      Binders
# 9   OFF-BI-10003910  Office Supplies      Binders
# 10  OFF-LA-10000240  Office Supplies       Labels
# 11  OFF-LA-10000240  Office Supplies       Labels
# 12  OFF-PA-10002365  Office Supplies        Paper
# 13  OFF-PA-10002365  Office Supplies        Paper
# 14  OFF-PA-10002365  Office Supplies        Paper
# 15  OFF-ST-10000760  Office Supplies      Storage
# 16  TEC-PH-10002033       Technology       Phones
# 17  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2   Eldon Expressions Wood and Plastic Desk Access...
# 3       Bretford CR4500 Series Slim Rectangular Table
# 4       Bretford CR4500 Series Slim Rectangular Table
# 5            Chromcraft Rectangular Conference Tables
# 6                    Belkin F5C206VTEL 6 Outlet Surge
# 7                                          Newell 322
# 8         Fellowes PB200 Plastic Comb Binding Machine
# 9   DXL Angle-View Binders with Locking Rings by S...
# 10  Self-Adhesive Address Labels for Typewriters b...
# 11  Self-Adhesive Address Labels for Typewriters b...
# 12                                         Xerox 1967
# 13                                         Xerox 1967
# 14                                         Xerox 1967
# 15                     Eldon Fold 'N Roll Cart System
# 16    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 17                     Mitel 5320 IP Phone VoIP phone

# %%
# fechting only customers details who have orders
query = "select * from orders  \
right join customers on orders.customer_id=customers.customer_id \
right join products  on orders.product_id = products.product_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (18, 15)
#           order_id  order_date customer_id       product_id   sales  quantity  \
# 0   CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960       2.0
# 1             None        None        None             None     NaN       NaN
# 2   CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860       7.0
# 3   CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530       3.0
# 4   US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650       5.0
# 5             None        None        None             None     NaN       NaN
# 6             None        None        None             None     NaN       NaN
# 7             None        None        None             None     NaN       NaN
# 8             None        None        None             None     NaN       NaN
# 9             None        None        None             None     NaN       NaN
# 10  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620       2.0
# 11  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620       5.0
# 12  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552       1.0
# 13  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552       2.0
# 14  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552       3.0
# 15            None        None        None             None     NaN       NaN
# 16            None        None        None             None     NaN       NaN
# 17            None        None        None             None     NaN       NaN
#
#    customer_id    customer_name             city           state  postal_code  \
# 0     CG-12520      Claire Gute        Henderson        Kentucky      42420.0
# 1         None             None             None            None          NaN
# 2     BH-11710  Brosina Hoffman      Los Angeles      California      90032.0
# 3     BH-11710  Brosina Hoffman      Los Angeles      California      90032.0
# 4     SO-20335   Sean O'Donnell  Fort Lauderdale         Florida      33311.0
# 5         None             None             None            None          NaN
# 6         None             None             None            None          NaN
# 7         None             None             None            None          NaN
# 8         None             None             None            None          NaN
# 9         None             None             None            None          NaN
# 10    DV-13045  Darrin Van Huff      Los Angeles      California      90036.0
# 11    BH-11710  Brosina Hoffman      Los Angeles      California      90032.0
# 12    DV-13045  Darrin Van Huff      Los Angeles      California      90036.0
# 13    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida      33311.0
# 14    AA-10480     Andrew Allen          Concord  North Carolina      28027.0
# 15        None             None             None            None          NaN
# 16        None             None             None            None          NaN
# 17        None             None             None            None          NaN
#
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10000577        Furniture       Tables
# 5   FUR-TA-10001539        Furniture       Tables
# 6   OFF-AP-10002892  Office Supplies   Appliances
# 7   OFF-AR-10002833  Office Supplies          Art
# 8   OFF-BI-10003656  Office Supplies      Binders
# 9   OFF-BI-10003910  Office Supplies      Binders
# 10  OFF-LA-10000240  Office Supplies       Labels
# 11  OFF-LA-10000240  Office Supplies       Labels
# 12  OFF-PA-10002365  Office Supplies        Paper
# 13  OFF-PA-10002365  Office Supplies        Paper
# 14  OFF-PA-10002365  Office Supplies        Paper
# 15  OFF-ST-10000760  Office Supplies      Storage
# 16  TEC-PH-10002033       Technology       Phones
# 17  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2   Eldon Expressions Wood and Plastic Desk Access...
# 3       Bretford CR4500 Series Slim Rectangular Table
# 4       Bretford CR4500 Series Slim Rectangular Table
# 5            Chromcraft Rectangular Conference Tables
# 6                    Belkin F5C206VTEL 6 Outlet Surge
# 7                                          Newell 322
# 8         Fellowes PB200 Plastic Comb Binding Machine
# 9   DXL Angle-View Binders with Locking Rings by S...
# 10  Self-Adhesive Address Labels for Typewriters b...
# 11  Self-Adhesive Address Labels for Typewriters b...
# 12                                         Xerox 1967
# 13                                         Xerox 1967
# 14                                         Xerox 1967
# 15                     Eldon Fold 'N Roll Cart System
# 16    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 17                     Mitel 5320 IP Phone VoIP phone

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Quick Assessment

# %% [raw]
# Fetch Orders information of the customers from the California State.

# %% [raw]
# Fetch Orders information of customers from california who ordered furnitures.

# %%
data.to_sql('customers1', con=conn, index=True)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     691         while True:
# --> 692             packet_header = self._read_bytes(4)
#     693             # if DEBUG: dump_packet(packet_header)
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     737                 self._force_close()
# --> 738                 raise err.OperationalError(
#     739                     CR.CR_SERVER_LOST,
#
# OperationalError: (2013, 'Lost connection to MySQL server during query ([WinError 10054] An existing connection was forcibly closed by the remote host)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-27-e0d0cbf6d0d6> in <module>
# ----> 1 data.to_sql('customers1', con=conn, index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1338
#    1339     def has_table(self, name, schema=None):
# -> 1340         return self.connectable.run_callable(
#    1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2213         """
#    2214         with self._contextual_connect() as conn:
# -> 2215             return conn.run_callable(callable_, *args, **kwargs)
#    2216
#    2217     def execute(self, statement, *multiparams, **params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    1652
#    1653         """
# -> 1654         return callable_(self, *args, **kwargs)
#    1655
#    1656     def _run_visitor(self, visitorcallable, element, **kwargs):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py in has_table(self, connection, table_name, schema)
#    2478         try:
#    2479             try:
# -> 2480                 rs = connection.execution_options(
#    2481                     skip_user_error_events=True
#    2482                 ).execute(st)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1173         dialect = self.dialect
#    1174         parameters = _distill_params(multiparams, params)
# -> 1175         ret = self._execute_context(
#    1176             dialect,
#    1177             dialect.execution_ctx_cls._init_statement,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     690         buff = bytearray()
#     691         while True:
# --> 692             packet_header = self._read_bytes(4)
#     693             # if DEBUG: dump_packet(packet_header)
#     694
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     736                     continue
#     737                 self._force_close()
# --> 738                 raise err.OperationalError(
#     739                     CR.CR_SERVER_LOST,
#     740                     "Lost connection to MySQL server during query (%s)" % (e,),
#
# OperationalError: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query ([WinError 10054] An existing connection was forcibly closed by the remote host)')
# [SQL: DESCRIBE `customers1`]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
